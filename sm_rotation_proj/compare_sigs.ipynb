# %%
# Use sourmash compare to compare signatures that were calculated with 
# the same k size, the same molecule type, and the same encoding (e.g. dayoff or h-p).

# Take a look at the metapallette paper for some applications of k-sizes to detection of relatedness across
# evolutionary distances, or take our word that k = 21 ~ genus level similarlity, k = 31 ~ species level 
# similarity, and k = 51 ~ strain level similarity. https://msystems.asm.org/content/1/3/e00020-16

# %%
# %%bash
# less calcd_k_amino_acids.txt
#
# less calcd_k_nuclc_acids.txt
# Out:
# 7 12 15
# 21 31 51

# %%
# %%bash
#
#
# for org in bacteroides denticola gingivalis
# do
#     for mol in genomic rna
#     do
#         for k in 21 31 51
#         do
#         #Makes a compare folder for each k size
#             mkdir -p $org/$mol/sm_compare_tables
#
#             sourmash compare -k $k -o ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare  ${org}/${mol}/sigs/*.sig
#
#
#         #Makes a folder for sm_compare_table
#             mkdir -p $org/$mol/sm_plots
#             sourmash plot --output-dir ${org}/${mol}/sm_plots --labels --pdf  ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare
#
#
#         #This is probably computationally redundant
#             mkdir -p $org/$mol/sm_comp_CSVs
#             sourmash compare -k $k --csv ${org}/${mol}/sm_comp_CSVs/${org}_k${k}_${mol}_compare.csv $org/$mol/sigs/*.sig
#         done
#
#      #once per $org/$mol
#      #Send the .csv's and the pdfs to the Windows desktop
#             cp $org/$mol/sm_plots/*.pdf /mnt/c/Users/user/Desktop/Sourmash_Outputs/PDFs/
#             cp $org/$mol/sm_comp_CSVs/*.csv /mnt/c/Users/user/Desktop/Sourmash_Outputs/CSVs/
#
#     done
#
# done
# Out:
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# Error in parsing signature; quitting.
# ...

# %%
# %%bash
#
# pwd
# Out:
# /home/hehouts/2019-fall-rotation-dib/sm_rotation_proj

# %%
# %%bash
#
#
# for org in  bacteroides/
# #bacteroides denticola
# do
#     for mol in protein
#     do
#         for k in 7
#         #12 15
#         do
#         #Makes a compare folder for each k size
#             mkdir -p $org/$mol/sm_compare_tables
#             sourmash compare --protein -k $k -o ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare  ${org}/${mol}/sigs/*.sig
#             sourmash compare --dayhoff -k $k -o ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare  ${org}/${mol}/sigs/*.sig
#             sourmash compare --hp -k $k -o ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare  ${org}/${mol}/sigs/*.sig
#
#
#         #Makes a folder for sm_compare_table
#             mkdir -p $org/$mol/sm_plots
#             sourmash plot --output-dir ${org}/${mol}/sm_plots --labels --pdf  ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare
#
#
#         #This is probably computationally redundant
#             mkdir -p $org/$mol/sm_comp_CSVs
#             sourmash compare -k $k --csv ${org}/${mol}/sm_comp_CSVs/${org}_k${k}_${mol}_compare.csv $org/$mol/sigs/*.sig
#         done
#
#
#      #once per $org/$mol
#      #Send the .csv's and the pdfs to the Windows desktop
#             cp $org/$mol/sm_plots/*.pdf /mnt/c/Users/user/Desktop/Sourmash_Outputs/PDFs/
#             cp $org/$mol/sm_comp_CSVs/*.csv /mnt/c/Users/user/Desktop/Sourmash_Outputs/CSVs/
#
#     done
#
# done
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading bacteroides/protein/sigs/GCA_000011065.1_ASM1106v1_protein.sig
# ...
# loading bacteroides/protein/sigs/GCA_000157015.1_ASM15701v1_protein.sig
# ...
# loading bacteroides/protein/sigs/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# ...
# loading bacteroides/protein/sigs/GCA_000163055.2_ASM16305v2_protein.sig
# ...
# loading bacteroides/protein/sigs/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# ...
# loading bacteroides/protein/sigs/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# ...
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# ...
# loading bacteroides/protein/sigs/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# ...
# loading bacteroides/protein/sigs/GCA_000431275.1_MGS755_protein.sig
# ...
# loading bacteroides/protein/sigs/GCA_000432495.1_MGS558_protein.sig
# ...

# %%
# !sourmash compare --help
# Out:
# usage: sourmash [-o OUTPUT] [--ignore-abundance] [-k KSIZE] [--protein]
#                 [--no-protein] [--dayhoff] [--no-dayhoff] [--hp] [--no-hp]
#                 [--dna] [--no-dna] [--traverse-directory] [--csv CSV]
#                 [-p PROCESSES] [-q]
#                 signatures [signatures ...]
# sourmash: error: the following arguments are required: signatures

# %%
# %%bash
#
#
#
# ##This may have issues, and is redundant from above cell
#
# for org in bacteroides denticola gingivalis
# do
#
#     for mol in protein
#     do
#         for k in 7
# #12 15
#         do
#
#          #Makes a compare folder for each k size
#             mkdir -p $org/$mol/sm_compare_tables
#             sourmash compare -k $k -o ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare  ${org}/${mol}/sigs/*.sig
#
#         #Makes a folder for sm_compare_table
#             mkdir -p $org/$mol/sm_plots
#             sourmash plot --output-dir ${org}/${mol}/sm_plots --labels --pdf  ${org}/${mol}/sm_compare_tables/${org}_k${k}_${mol}_compare
#
#         #This is probably computationally redundant
#             mkdir -p $org/$mol/sm_comp_CSVs
#             sourmash compare -k $k --csv ${org}/${mol}/sm_comp_CSVs/${org}_k${k}_${mol}_compare.csv $org/$mol/sigs/*.sig
#         done
#
#          #once per $org/$mol
#          #Send the .csv's and the pdfs to the Windows desktop
#             cp $org/$mol/sm_plots/*.pdf /mnt/c/Users/user/Desktop/Sourmash_Outputs/PDFs/
#             cp $org/$mol/sm_comp_CSVs/*.csv /mnt/c/Users/user/Desktop/Sourmash_Outputs/CSVs/
#
#     done
# done
# Out:
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# ...
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# ...
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# ...
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# ...
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# ...
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
# ...

# %%
# %%bash
#
# ##giving up on this proj for now
#
#
#
# for org in bacteroides
# #denticola gingivalis
# do
#     for mol in genomic
# #rna
#     do
#         read calc_
#         for k in read calcd_k_nuclc_acids.txt
#         do
#
#         mkdir -p $org/$mol/sm_compare_tables/k$k
#         sourmash compare -k $k -o $org/$mol/sm_compare_tables/k$k $org/$mol/sigs/*.sig
#
#         done
#     done
# done
# Out:
# bash: line 9: syntax error near unexpected token `<'
# bash: line 9: `        for k in < calcd_k_nuclc_acids.txt'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-8-88ce4659dddc> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\n\nfor org in bacteroides \n#denticola gingivalis\ndo\n    for mol in genomic\n#rna \n    do\n        for k in < calcd_k_nuclc_acids.txt\n        do\n        \n        mkdir -p $org/$mol/sm_compare_tables/k$k\n        sourmash compare -k $k -o $org/$mol/sm_compare_tables/k$k $org/$mol/sigs/*.sig\n        \n        done\n    done\ndone\n\n')
#
# ~/miniconda3/envs/rotation/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# ...
