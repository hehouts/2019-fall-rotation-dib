# %%
    #activate environment
#conda activate rotation
    #install pandas, os, re, argparse, ipfsapi, requests, shutil; e.g.
#conda install pandas

# %%
# %%bash
#
# mkdir github_source_files
# cd github_souce_files
#
# git clone https://github.com/bluegenes/2018-test_datasets.git
#
# cp 2018-test_datasets/* .
# rm -r 2018-test_datasets
# Out:
# /home/hehouts/2019-fall-rotation-dib/sm_rotation_proj

# %%
# %%bash
# #This should be better than the below block, but is not tested.
# #Hypothetically, new organisms can be added willy nilly
#
# for org in bacteroides denticola gingivalis
# do
#     for mol in genomic protein  rna
#     do
#
#         #Downloads seqs
#         python github_souce_files/download_genbank_datasets.py --genbank --protein --rna --subfolder github_souce_files/$org.csv
#
#         #This organizes folders
#         mv github_souce_files/$org.csv github_souce_files/$org/
#         mkdir -p $org
#         mv github_souce_files/$org/* $org
#         rmdir github_souce_files/$org/
#
#         cd $org
#         mkdir $mol/seqs
#         mv $mol/*.gz $mol/seqs
#         cd ..
#     done
# done

# %%
# %%bash
#
# #REDUNDANT
#
# python github_souce_files/download_genbank_datasets.py --genbank --protein --rna --subfolder github_souce_files/bacteroides.csv
#
# python github_souce_files/download_genbank_datasets.py --genbank --protein --rna --subfolder github_souce_files/denticola.csv
#
# python github_souce_files/download_genbank_datasets.py --genbank --protein --rna --subfolder github_souce_files/gingivalis.csv
#
#
# #This organizes folders
# mv github_souce_files/bacteroides.csv github_souce_files/bacteroides/
# mkdir -p bacteroides
# mv github_souce_files/bacteroides/* bacteroides
# rmdir github_souce_files/bacteroides/
#
# mv github_souce_files/denticola.csv github_souce_files/denticola
# mkdir denticola
# mv github_souce_files/denticola/* denticola
# rmdir github_souce_files/denticola/
#
# mv github_souce_files/gingivalis.csv github_souce_files/gingivalis
# mkdir gingivalis
# mv github_souce_files/gingivalis/* gingivalis
# rmdir github_souce_files/gingivalis/
#
#
#
# #This is to organize seqs
# for org in bacteroides denticola gingivalis
#     do
#     for mol in genomic protein  rna
#     do
#         cd $org
#         mkdir $mol/seqs
#         mv $mol/*a.gz $mol/seqs
#         cd ..
#     done
# done

# %%
# %%bash
# #Calc signatures
#
#
# for org in bacteroides denticola gingivalis
# do
#     for mol in genomic rna
#     do
#         cd $org
#         mkdir $mol/sigs
#         for infile in $mol/seqs/*a.gz
#         do
#         for k in 21 31 51
#         do
#
#             out_name=$(basename $infile .fna.gz)
#             sourmash compute -k $k --scaled 2000 --track-abundance -o $mol/sigs/${out_name}.sig ${infile}
#
#             #back to relative home dir, overwrite and append this file
#             cd ..
#             echo "$k" >calcd_k_nuclc_acids.txt
#         done
#         done
#     done
#
#
#     for mol in protein
#     do
#
#         cd $org
#         mkdir $mol/sigs
#         for infile in $mol/seqs/*a.gz
#         do
#         for k in 7 12 15
#         do
#             out_name=$(basename $infile .faa.gz)
#             sourmash compute --input-is-protein -k $k --scaled 2000 --track-abundance -o $mol/sigs/${out_name}.sig ${infile}
#
#            #back to relative home dir, overwrite and append this file
#             cd ..
#             echo "$k" >calcd_k_amino_acids.txt
#         done
#         done
#     done
#
#
# done
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000147075.1_ASM14707v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000147075.1_ASM14707v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000147075.1_ASM14707v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000216715.2_CLC_glsol140_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000216715.2_CLC_glsol140_genomic.fna.gz
# calculated 3 signatures for 316 sequences in genomic/seqs/GCA_000216715.2_CLC_glsol140_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000217015.3_CLC_glsol119_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000217015.3_CLC_glsol119_genomic.fna.gz
# calculated 3 signatures for 338 sequences in genomic/seqs/GCA_000217015.3_CLC_glsol119_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000217655.1_ASM21765v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000217655.1_ASM21765v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000217655.1_ASM21765v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000222305.1_ASM22230v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000222305.1_ASM22230v1_genomic.fna.gz
# calculated 3 signatures for 17 sequences in genomic/seqs/GCA_000222305.1_ASM22230v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000236685.1_ASM23668v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000236685.1_ASM23668v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000236685.1_ASM23668v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000239475.1_ASM23947v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000239475.1_ASM23947v1_genomic.fna.gz
# calculated 3 signatures for 3 sequences in genomic/seqs/GCA_000239475.1_ASM23947v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000242595.3_ASM24259v3_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000242595.3_ASM24259v3_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000242595.3_ASM24259v3_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000246415.2_CLC_glsol068_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000246415.2_CLC_glsol068_genomic.fna.gz
# calculated 3 signatures for 667 sequences in genomic/seqs/GCA_000246415.2_CLC_glsol068_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000246815.1_ASM24681v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000246815.1_ASM24681v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000246815.1_ASM24681v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000260795.1_ASM26079v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000260795.1_ASM26079v1_genomic.fna.gz
# calculated 3 signatures for 147 sequences in genomic/seqs/GCA_000260795.1_ASM26079v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000301975.1_ASM30197v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000301975.1_ASM30197v1_genomic.fna.gz
# calculated 3 signatures for 116 sequences in genomic/seqs/GCA_000301975.1_ASM30197v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000338595.1_Trep_dent_ATCC_33521_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000338595.1_Trep_dent_ATCC_33521_V1_genomic.fna.gz
# calculated 3 signatures for 3 sequences in genomic/seqs/GCA_000338595.1_Trep_dent_ATCC_33521_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000338615.1_Trep_dent_ATCC_33520_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000338615.1_Trep_dent_ATCC_33520_V1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in genomic/seqs/GCA_000338615.1_Trep_dent_ATCC_33520_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000338635.1_Trep_dent_ASLM_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000338635.1_Trep_dent_ASLM_V1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in genomic/seqs/GCA_000338635.1_Trep_dent_ASLM_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000340605.1_Trep_dent_H1-T_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000340605.1_Trep_dent_H1-T_V1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000340605.1_Trep_dent_H1-T_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000340645.1_Trep_dent_H-22_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000340645.1_Trep_dent_H-22_V1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000340645.1_Trep_dent_H-22_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000340725.1_Trep_dent_AL-2_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000340725.1_Trep_dent_AL-2_V1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000340725.1_Trep_dent_AL-2_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000340745.1_Trep_dent_US-Trep_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000340745.1_Trep_dent_US-Trep_V1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in genomic/seqs/GCA_000340745.1_Trep_dent_US-Trep_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000342705.1_CA_glsol153_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000342705.1_CA_glsol153_genomic.fna.gz
# calculated 3 signatures for 140 sequences in genomic/seqs/GCA_000342705.1_CA_glsol153_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000343205.1_CA_glsol121_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000343205.1_CA_glsol121_genomic.fna.gz
# calculated 3 signatures for 162 sequences in genomic/seqs/GCA_000343205.1_CA_glsol121_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000382565.1_ASM38256v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000382565.1_ASM38256v1_genomic.fna.gz
# calculated 3 signatures for 7 sequences in genomic/seqs/GCA_000382565.1_ASM38256v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000413075.1_Trep_dent_SP44_F0466_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000413075.1_Trep_dent_SP44_F0466_V1_genomic.fna.gz
# calculated 3 signatures for 8 sequences in genomic/seqs/GCA_000413075.1_Trep_dent_SP44_F0466_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000413095.1_Trep_dent_SP32_F0464_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000413095.1_Trep_dent_SP32_F0464_V1_genomic.fna.gz
# calculated 3 signatures for 6 sequences in genomic/seqs/GCA_000413095.1_Trep_dent_SP32_F0464_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000413115.1_Trep_dent_SP23_F0463_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000413115.1_Trep_dent_SP23_F0463_V1_genomic.fna.gz
# calculated 3 signatures for 3 sequences in genomic/seqs/GCA_000413115.1_Trep_dent_SP23_F0463_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000426705.1_ASM42670v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000426705.1_ASM42670v1_genomic.fna.gz
# calculated 3 signatures for 29 sequences in genomic/seqs/GCA_000426705.1_ASM42670v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000465015.1_Treponema_pedis_T_M1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000465015.1_Treponema_pedis_T_M1_genomic.fna.gz
# calculated 3 signatures for 558 sequences in genomic/seqs/GCA_000465015.1_Treponema_pedis_T_M1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000468055.1_ASM46805v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000468055.1_ASM46805v1_genomic.fna.gz
# calculated 3 signatures for 21 sequences in genomic/seqs/GCA_000468055.1_ASM46805v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000500065.1_AB2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000500065.1_AB2_genomic.fna.gz
# calculated 3 signatures for 168 sequences in genomic/seqs/GCA_000500065.1_AB2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000501035.1_BorGarIPT95_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000501035.1_BorGarIPT95_genomic.fna.gz
# calculated 3 signatures for 194 sequences in genomic/seqs/GCA_000501035.1_BorGarIPT95_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000501115.1_BorGarIPT101_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000501115.1_BorGarIPT101_genomic.fna.gz
# calculated 3 signatures for 713 sequences in genomic/seqs/GCA_000501115.1_BorGarIPT101_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000501555.1_BorAfzIPT109_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000501555.1_BorAfzIPT109_genomic.fna.gz
# calculated 3 signatures for 537 sequences in genomic/seqs/GCA_000501555.1_BorAfzIPT109_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000502195.1_BorAfzIPT138_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000502195.1_BorAfzIPT138_genomic.fna.gz
# calculated 3 signatures for 193 sequences in genomic/seqs/GCA_000502195.1_BorAfzIPT138_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000507245.1_ASM50724v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000507245.1_ASM50724v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000507245.1_ASM50724v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000537795.1_Stap_aure_SMMC6007_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000537795.1_Stap_aure_SMMC6007_V1_genomic.fna.gz
# calculated 3 signatures for 10 sequences in genomic/seqs/GCA_000537795.1_Stap_aure_SMMC6007_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000568735.2_ASM56873v2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000568735.2_ASM56873v2_genomic.fna.gz
# calculated 3 signatures for 74 sequences in genomic/seqs/GCA_000568735.2_ASM56873v2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000758165.1_Spiroch1.0_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000758165.1_Spiroch1.0_genomic.fna.gz
# calculated 3 signatures for 72 sequences in genomic/seqs/GCA_000758165.1_Spiroch1.0_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000768055.1_ASM76805v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000768055.1_ASM76805v1_genomic.fna.gz
# calculated 3 signatures for 275 sequences in genomic/seqs/GCA_000768055.1_ASM76805v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000775995.1_ASM77599v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000775995.1_ASM77599v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_000775995.1_ASM77599v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000802305.1_ASM80230v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000802305.1_ASM80230v1_genomic.fna.gz
# calculated 3 signatures for 55 sequences in genomic/seqs/GCA_000802305.1_ASM80230v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000818865.1_ASM81886v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000818865.1_ASM81886v1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in genomic/seqs/GCA_000818865.1_ASM81886v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_000941035.1_ASM94103v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_000941035.1_ASM94103v1_genomic.fna.gz
# calculated 3 signatures for 5 sequences in genomic/seqs/GCA_000941035.1_ASM94103v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001281815.1_ASM128181v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001281815.1_ASM128181v1_genomic.fna.gz
# calculated 3 signatures for 286 sequences in genomic/seqs/GCA_001281815.1_ASM128181v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001405175.1_13470_2_54_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001405175.1_13470_2_54_genomic.fna.gz
# calculated 3 signatures for 72 sequences in genomic/seqs/GCA_001405175.1_13470_2_54_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001443305.1_ASM144330v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001443305.1_ASM144330v1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in genomic/seqs/GCA_001443305.1_ASM144330v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001567655.1_ASM156765v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001567655.1_ASM156765v1_genomic.fna.gz
# calculated 3 signatures for 255 sequences in genomic/seqs/GCA_001567655.1_ASM156765v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001604335.1_ASM160433v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001604335.1_ASM160433v1_genomic.fna.gz
# calculated 3 signatures for 592 sequences in genomic/seqs/GCA_001604335.1_ASM160433v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001712955.1_ASM171295v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001712955.1_ASM171295v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_001712955.1_ASM171295v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001713255.1_ASM171325v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001713255.1_ASM171325v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in genomic/seqs/GCA_001713255.1_ASM171325v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001746215.1_ASM174621v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001746215.1_ASM174621v1_genomic.fna.gz
# calculated 3 signatures for 178 sequences in genomic/seqs/GCA_001746215.1_ASM174621v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001829125.1_ASM182912v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001829125.1_ASM182912v1_genomic.fna.gz
# calculated 3 signatures for 273 sequences in genomic/seqs/GCA_001829125.1_ASM182912v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001829165.1_ASM182916v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001829165.1_ASM182916v1_genomic.fna.gz
# calculated 3 signatures for 373 sequences in genomic/seqs/GCA_001829165.1_ASM182916v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001829295.1_ASM182929v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001829295.1_ASM182929v1_genomic.fna.gz
# calculated 3 signatures for 138 sequences in genomic/seqs/GCA_001829295.1_ASM182929v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001829415.1_ASM182941v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001829415.1_ASM182941v1_genomic.fna.gz
# calculated 3 signatures for 77 sequences in genomic/seqs/GCA_001829415.1_ASM182941v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001829475.1_ASM182947v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001829475.1_ASM182947v1_genomic.fna.gz
# calculated 3 signatures for 209 sequences in genomic/seqs/GCA_001829475.1_ASM182947v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001829505.1_ASM182950v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001829505.1_ASM182950v1_genomic.fna.gz
# calculated 3 signatures for 245 sequences in genomic/seqs/GCA_001829505.1_ASM182950v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001830585.1_ASM183058v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001830585.1_ASM183058v1_genomic.fna.gz
# calculated 3 signatures for 267 sequences in genomic/seqs/GCA_001830585.1_ASM183058v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001830635.1_ASM183063v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001830635.1_ASM183063v1_genomic.fna.gz
# calculated 3 signatures for 67 sequences in genomic/seqs/GCA_001830635.1_ASM183063v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001894145.1_ASM189414v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001894145.1_ASM189414v1_genomic.fna.gz
# calculated 3 signatures for 440 sequences in genomic/seqs/GCA_001894145.1_ASM189414v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001896735.1_ASM189673v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001896735.1_ASM189673v1_genomic.fna.gz
# calculated 3 signatures for 160 sequences in genomic/seqs/GCA_001896735.1_ASM189673v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_001940825.1_ASM194082v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_001940825.1_ASM194082v1_genomic.fna.gz
# calculated 3 signatures for 72 sequences in genomic/seqs/GCA_001940825.1_ASM194082v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_002009835.1_ASM200983v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_002009835.1_ASM200983v1_genomic.fna.gz
# calculated 3 signatures for 337 sequences in genomic/seqs/GCA_002009835.1_ASM200983v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_002069655.1_ASM206965v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_002069655.1_ASM206965v1_genomic.fna.gz
# calculated 3 signatures for 122 sequences in genomic/seqs/GCA_002069655.1_ASM206965v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_002069965.1_ASM206996v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_002069965.1_ASM206996v1_genomic.fna.gz
# calculated 3 signatures for 160 sequences in genomic/seqs/GCA_002069965.1_ASM206996v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_900018035.1_7521_5_26_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_900018035.1_7521_5_26_genomic.fna.gz
# calculated 3 signatures for 72 sequences in genomic/seqs/GCA_900018035.1_7521_5_26_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_900147745.1_138_1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_900147745.1_138_1_genomic.fna.gz
# calculated 3 signatures for 282 sequences in genomic/seqs/GCA_900147745.1_138_1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 65 sequences in genomic/seqs/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_900164975.1_16852_2_85_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_900164975.1_16852_2_85_genomic.fna.gz
# calculated 3 signatures for 31 sequences in genomic/seqs/GCA_900164975.1_16852_2_85_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: genomic/seqs/GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from genomic/seqs/GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 32 sequences in genomic/seqs/GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_genomic.fna.gz
# bash: line 8: cd: denticola: No such file or directory
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000147075.1_ASM14707v1_rna_from_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from rna/seqs/GCA_000147075.1_ASM14707v1_rna_from_genomic.fna.gz
# calculated 3 signatures for 52 sequences in rna/seqs/GCA_000147075.1_ASM14707v1_rna_from_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000216715.2_CLC_glsol140_rna_from_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from rna/seqs/GCA_000216715.2_CLC_glsol140_rna_from_genomic.fna.gz
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/command_compute.py", line 567, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for 'rna/seqs/GCA_000216715.2_CLC_glsol140_rna_from_genomic.fna.gz'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000217015.3_CLC_glsol119_rna_from_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from rna/seqs/GCA_000217015.3_CLC_glsol119_rna_from_genomic.fna.gz
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/command_compute.py", line 567, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for 'rna/seqs/GCA_000217015.3_CLC_glsol119_rna_from_genomic.fna.gz'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000217655.1_ASM21765v1_rna_from_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from rna/seqs/GCA_000217655.1_ASM21765v1_rna_from_genomic.fna.gz
# calculated 3 signatures for 54 sequences in rna/seqs/GCA_000217655.1_ASM21765v1_rna_from_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000222305.1_ASM22230v1_rna_from_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from rna/seqs/GCA_000222305.1_ASM22230v1_rna_from_genomic.fna.gz
# calculated 3 signatures for 38 sequences in rna/seqs/GCA_000222305.1_ASM22230v1_rna_from_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000236685.1_ASM23668v1_rna_from_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from rna/seqs/GCA_000236685.1_ASM23668v1_rna_from_genomic.fna.gz
# calculated 3 signatures for 67 sequences in rna/seqs/GCA_000236685.1_ASM23668v1_rna_from_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000239475.1_ASM23947v1_rna_from_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from rna/seqs/GCA_000239475.1_ASM23947v1_rna_from_genomic.fna.gz
# calculated 3 signatures for 36 sequences in rna/seqs/GCA_000239475.1_ASM23947v1_rna_from_genomic.fna.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: rna/seqs/GCA_000242595.3_ASM24259v3_rna_from_genomic.fna.gz
# ...
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001829125.1_ASM182912v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001829125.1_ASM182912v1_protein.faa.gz
# calculated 3 signatures for 3454 sequences in protein/seqs/GCA_001829125.1_ASM182912v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001829165.1_ASM182916v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001829165.1_ASM182916v1_protein.faa.gz
# calculated 3 signatures for 4234 sequences in protein/seqs/GCA_001829165.1_ASM182916v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001829295.1_ASM182929v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001829295.1_ASM182929v1_protein.faa.gz
# calculated 3 signatures for 2893 sequences in protein/seqs/GCA_001829295.1_ASM182929v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001829415.1_ASM182941v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001829415.1_ASM182941v1_protein.faa.gz
# calculated 3 signatures for 3176 sequences in protein/seqs/GCA_001829415.1_ASM182941v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001829475.1_ASM182947v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001829475.1_ASM182947v1_protein.faa.gz
# calculated 3 signatures for 2271 sequences in protein/seqs/GCA_001829475.1_ASM182947v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001829505.1_ASM182950v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001829505.1_ASM182950v1_protein.faa.gz
# calculated 3 signatures for 2855 sequences in protein/seqs/GCA_001829505.1_ASM182950v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001830585.1_ASM183058v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001830585.1_ASM183058v1_protein.faa.gz
# calculated 3 signatures for 3119 sequences in protein/seqs/GCA_001830585.1_ASM183058v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001830635.1_ASM183063v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001830635.1_ASM183063v1_protein.faa.gz
# calculated 3 signatures for 2898 sequences in protein/seqs/GCA_001830635.1_ASM183063v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001894145.1_ASM189414v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001894145.1_ASM189414v1_protein.faa.gz
# calculated 3 signatures for 5527 sequences in protein/seqs/GCA_001894145.1_ASM189414v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001896735.1_ASM189673v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001896735.1_ASM189673v1_protein.faa.gz
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/command_compute.py", line 567, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for 'protein/seqs/GCA_001896735.1_ASM189673v1_protein.faa.gz'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_001940825.1_ASM194082v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_001940825.1_ASM194082v1_protein.faa.gz
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/command_compute.py", line 567, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for 'protein/seqs/GCA_001940825.1_ASM194082v1_protein.faa.gz'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_002009835.1_ASM200983v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_002009835.1_ASM200983v1_protein.faa.gz
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/command_compute.py", line 567, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for 'protein/seqs/GCA_002009835.1_ASM200983v1_protein.faa.gz'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_002069655.1_ASM206965v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_002069655.1_ASM206965v1_protein.faa.gz
# calculated 3 signatures for 2059 sequences in protein/seqs/GCA_002069655.1_ASM206965v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_002069965.1_ASM206996v1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_002069965.1_ASM206996v1_protein.faa.gz
# calculated 3 signatures for 2775 sequences in protein/seqs/GCA_002069965.1_ASM206996v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_900018035.1_7521_5_26_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_900018035.1_7521_5_26_protein.faa.gz
# calculated 3 signatures for 2780 sequences in protein/seqs/GCA_900018035.1_7521_5_26_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_900147745.1_138_1_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_900147745.1_138_1_protein.faa.gz
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/command_compute.py", line 567, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for 'protein/seqs/GCA_900147745.1_138_1_protein.faa.gz'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 2898 sequences in protein/seqs/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_900164975.1_16852_2_85_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_900164975.1_16852_2_85_protein.faa.gz
# calculated 3 signatures for 3654 sequences in protein/seqs/GCA_900164975.1_16852_2_85_protein.faa.gz
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: protein/seqs/GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 12, 15]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from protein/seqs/GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 2193 sequences in protein/seqs/GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_protein.faa.gz
# saved signature(s) to protein/sigs/GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_protein.sig. Note: signature license is CC0.

# %%
# %%bash
#
# echo "7 12 15" >calcd_k_amino_acids.txt
# echo "21 31 51" >calcd_k_nuclc_acids.txt
#
# less calcd_k_amino_acids.txt
#
# less calcd_k_nuclc_acids.txt
# Out:
# 7 12 15
# 21 31 51
