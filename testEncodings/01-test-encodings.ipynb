# %% [markdown]
# # Week 1 -- Testing protein encodings for similarity detection with sourmash

# %% [markdown]
# This notebook requires the following libraries: `pandas`, `requests`. Most of these libraries come with python, but you will get an error message if they are not installed: `ModuleNotFoundError: No module named 'pandas'`. To install something in your `rotation` environment, run:
#
# `$ conda activate rotation`
# `(rotation) $ conda install pandas`

# %% [markdown]
# ## Download data
#
# First download some data that we can use as a test set. We will download genomes, "transcriptomes" (computationally predicted RNA sequences from DNA), and amino acid sequences. We will use sequences that are related to species *Treponema denticola*, *Bacteroides thetaiotaomicron*, and *Porphyromonas gingivalis*. In the csv which we use to cue downloads, we have recorded the taxonomic relatedness of each bug that we download relative to our species of interest. We will use these levels to infer whether sourmash recapitulates known taxonomic relationships between sequences.

# %% [markdown]
# !git clone https://github.com/bluegenes/2018-test_datasets.git
#
# !python 2018-test_datasets/download_genbank_datasets.py --genbank --protein --rna --subfolder 2018-test_datasets/denticola.csv
# !python 2018-test_datasets/download_genbank_datasets.py --genbank --protein --rna --subfolder 2018-test_datasets/bacteroides.csv
# !python 2018-test_datasets/download_genbank_datasets.py --genbank --protein --rna --subfolder 2018-test_datasets/gingivalis.csv

# %%
# !git clone https://github.com/bluegenes/2018-test_datasets.git
# Out:
# fatal: destination path '2018-test_datasets' already exists and is not an empty directory.

# %%
# !python 2018-test_datasets/download_genbank_datasets.py --genbank --protein --rna --subfolder 2018-test_datasets/denticola.csv
# Out:
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/343/205/GCA_000343205.1_CA_glsol121/GCA_000343205.1_CA_glsol121_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/343/205/GCA_000343205.1_CA_glsol121/GCA_000343205.1_CA_glsol121_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/343/205/GCA_000343205.1_CA_glsol121/GCA_000343205.1_CA_glsol121_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/568/735/GCA_000568735.2_ASM56873v2/GCA_000568735.2_ASM56873v2_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/568/735/GCA_000568735.2_ASM56873v2/GCA_000568735.2_ASM56873v2_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/568/735/GCA_000568735.2_ASM56873v2/GCA_000568735.2_ASM56873v2_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/818/865/GCA_000818865.1_ASM81886v1/GCA_000818865.1_ASM81886v1_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/818/865/GCA_000818865.1_ASM81886v1/GCA_000818865.1_ASM81886v1_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/818/865/GCA_000818865.1_ASM81886v1/GCA_000818865.1_ASM81886v1_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/465/015/GCA_000465015.1_Treponema_pedis_T_M1/GCA_000465015.1_Treponema_pedis_T_M1_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/465/015/GCA_000465015.1_Treponema_pedis_T_M1/GCA_000465015.1_Treponema_pedis_T_M1_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/465/015/GCA_000465015.1_Treponema_pedis_T_M1/GCA_000465015.1_Treponema_pedis_T_M1_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/712/955/GCA_001712955.1_ASM171295v1/GCA_001712955.1_ASM171295v1_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/712/955/GCA_001712955.1_ASM171295v1/GCA_001712955.1_ASM171295v1_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/712/955/GCA_001712955.1_ASM171295v1/GCA_001712955.1_ASM171295v1_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/896/735/GCA_001896735.1_ASM189673v1/GCA_001896735.1_ASM189673v1_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/896/735/GCA_001896735.1_ASM189673v1/GCA_001896735.1_ASM189673v1_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/896/735/GCA_001896735.1_ASM189673v1/GCA_001896735.1_ASM189673v1_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/829/125/GCA_001829125.1_ASM182912v1/GCA_001829125.1_ASM182912v1_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/829/125/GCA_001829125.1_ASM182912v1/GCA_001829125.1_ASM182912v1_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/001/829/125/GCA_001829125.1_ASM182912v1/GCA_001829125.1_ASM182912v1_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/900/156/105/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/900/156/105/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/900/156/105/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly/GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/775/995/GCA_000775995.1_ASM77599v1/GCA_000775995.1_ASM77599v1_genomic.fna.gz
# protein: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/775/995/GCA_000775995.1_ASM77599v1/GCA_000775995.1_ASM77599v1_protein.faa.gz
# rna: https://ftp.ncbi.nih.gov/genomes/all/GCA/000/775/995/GCA_000775995.1_ASM77599v1/GCA_000775995.1_ASM77599v1_rna_from_genomic.fna.gz
# genome: https://ftp.ncbi.nih.gov/genomes/all/GCA/001
# GCA_000246815.1_ASM24681v1_genomic.fna.gz
# GCA_000260795.1_ASM26079v1_genomic.fna.gz
# GCA_000301975.1_ASM30197v1_genomic.fna.gz
# GCA_000338595.1_Trep_dent_ATCC_33521_V1_genomic.fna.gz
# GCA_000338615.1_Trep_dent_ATCC_33520_V1_genomic.fna.gz
# GCA_000338635.1_Trep_dent_ASLM_V1_genomic.fna.gz
# GCA_000340605.1_Trep_dent_H1-T_V1_genomic.fna.gz
# GCA_000340645.1_Trep_dent_H-22_V1_genomic.fna.gz
# GCA_000340725.1_Trep_dent_AL-2_V1_genomic.fna.gz
# GCA_000340745.1_Trep_dent_US-Trep_V1_genomic.fna.gz
# GCA_000342705.1_CA_glsol153_genomic.fna.gz
# GCA_000343205.1_CA_glsol121_genomic.fna.gz
# GCA_000382565.1_ASM38256v1_genomic.fna.gz
# GCA_000413075.1_Trep_dent_SP44_F0466_V1_genomic.fna.gz
# GCA_000413095.1_Trep_dent_SP32_F0464_V1_genomic.fna.gz
# GCA_000413115.1_Trep_dent_SP23_F0463_V1_genomic.fna.gz
# GCA_000426705.1_ASM42670v1_genomic.fna.gz
# GCA_000465015.1_Treponema_pedis_T_M1_genomic.fna.gz
# GCA_000468055.1_ASM46805v1_genomic.fna.gz
# GCA_000500065.1_AB2_genomic.fna.gz
# GCA_000501035.1_BorGarIPT95_genomic.fna.gz
# GCA_000501115.1_BorGarIPT101_genomic.fna.gz
# GCA_000501555.1_BorAfzIPT109_genomic.fna.gz
# GCA_000502195.1_BorAfzIPT138_genomic.fna.gz
# GCA_000507245.1_ASM50724v1_genomic.fna.gz
# GCA_000537795.1_Stap_aure_SMMC6007_V1_genomic.fna.gz
# GCA_000568735.2_ASM56873v2_genomic.fna.gz
# GCA_000758165.1_Spiroch1.0_genomic.fna.gz
# GCA_000768055.1_ASM76805v1_genomic.fna.gz
# GCA_000775995.1_ASM77599v1_genomic.fna.gz
# GCA_000802305.1_ASM80230v1_genomic.fna.gz
# GCA_000818865.1_ASM81886v1_genomic.fna.gz
# GCA_000941035.1_ASM94103v1_genomic.fna.gz
# GCA_001281815.1_ASM128181v1_genomic.fna.gz
# GCA_001405175.1_13470_2_54_genomic.fna.gz
# GCA_001443305.1_ASM144330v1_genomic.fna.gz
# GCA_001567655.1_ASM156765v1_genomic.fna.gz
# GCA_001604335.1_ASM160433v1_genomic.fna.gz
# GCA_001712955.1_ASM171295v1_genomic.fna.gz
# GCA_001713255.1_ASM171325v1_genomic.fna.gz
# GCA_001746215.1_ASM174621v1_genomic.fna.gz
# GCA_001829125.1_ASM182912v1_genomic.fna.gz
# GCA_001829165.1_ASM182916v1_genomic.fna.gz
# GCA_001829295.1_ASM182929v1_genomic.fna.gz
# GCA_001829415.1_ASM182941v1_genomic.fna.gz
# GCA_001829475.1_ASM182947v1_genomic.fna.gz
# GCA_001829505.1_ASM182950v1_genomic.fna.gz
# GCA_001830585.1_ASM183058v1_genomic.fna.gz
# GCA_001830635.1_ASM183063v1_genomic.fna.gz
# GCA_001894145.1_ASM189414v1_genomic.fna.gz
# GCA_001896735.1_ASM189673v1_genomic.fna.gz
# GCA_001940825.1_ASM194082v1_genomic.fna.gz
# GCA_002009835.1_ASM200983v1_genomic.fna.gz
# GCA_002069655.1_ASM206965v1_genomic.fna.gz
# GCA_002069965.1_ASM206996v1_genomic.fna.gz
# GCA_900018035.1_7521_5_26_genomic.fna.gz
# GCA_900147745.1_138_1_genomic.fna.gz
# GCA_900156105.1_IMG-taxon_2706795025_annotated_assembly_genomic.fna.gz
# GCA_900164975.1_16852_2_85_genomic.fna.gz
# GCA_900167145.1_IMG-taxon_2582581326_annotated_assembly_genomic.fna.gz

# %% [markdown]
# ## Generating signatures using sourmash
#
# We will generate signatures for our data. One signature can hold multiple k sizes, but only one scaled value and only one molecule type/encoding (i.e. DNA or protein).

# %%
# calculate signatures for RNA and DNA
# !mkdir -p sigs/bacteroides/genomic
# !for infile in 2018-test_datasets/bacteroides/genomic/*fna.gz; do out_name=$(basename $infile .fna.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/bacteroides/genomic/${out_name}.sig ${infile}; done
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000011065.1_ASM1106v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000011065.1_ASM1106v1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000011065.1_ASM1106v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000011065.1_ASM1106v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000157015.1_ASM15701v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000157015.1_ASM15701v1_genomic.fna.gz
# calculated 3 signatures for 33 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000157015.1_ASM15701v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000157015.1_ASM15701v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.fna.gz
# calculated 3 signatures for 5 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000163055.2_ASM16305v2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000163055.2_ASM16305v2_genomic.fna.gz
# calculated 3 signatures for 2 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000163055.2_ASM16305v2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000163055.2_ASM16305v2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.fna.gz
# calculated 3 signatures for 76 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.fna.gz
# calculated 3 signatures for 19 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000373705.1_ASM37370v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000373705.1_ASM37370v1_genomic.fna.gz
# calculated 3 signatures for 50 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000373705.1_ASM37370v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000373705.1_ASM37370v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.fna.gz
# calculated 3 signatures for 6 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000431275.1_MGS755_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000431275.1_MGS755_genomic.fna.gz
# calculated 3 signatures for 114 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000431275.1_MGS755_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000431275.1_MGS755_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000432495.1_MGS558_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000432495.1_MGS558_genomic.fna.gz
# calculated 3 signatures for 175 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000432495.1_MGS558_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000432495.1_MGS558_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000466425.1_ASM46642v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000466425.1_ASM46642v1_genomic.fna.gz
# calculated 3 signatures for 103 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000466425.1_ASM46642v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000466425.1_ASM46642v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000495955.1_NUHP2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000495955.1_NUHP2_genomic.fna.gz
# calculated 3 signatures for 59 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000495955.1_NUHP2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000495955.1_NUHP2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000501415.1_BorBurgIPT48_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000501415.1_BorBurgIPT48_genomic.fna.gz
# calculated 3 signatures for 395 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000501415.1_BorBurgIPT48_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000501415.1_BorBurgIPT48_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.fna.gz
# calculated 3 signatures for 13 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.fna.gz
# calculated 3 signatures for 48 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000598325.1_ASM59832v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000598325.1_ASM59832v1_genomic.fna.gz
# calculated 3 signatures for 449 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000598325.1_ASM59832v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000598325.1_ASM59832v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000611675.1_ASM61167v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000611675.1_ASM61167v1_genomic.fna.gz
# calculated 3 signatures for 48 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000611675.1_ASM61167v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000611675.1_ASM61167v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000614865.1_ASM61486v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000614865.1_ASM61486v1_genomic.fna.gz
# calculated 3 signatures for 92 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000614865.1_ASM61486v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000614865.1_ASM61486v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000614895.1_ASM61489v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000614895.1_ASM61489v1_genomic.fna.gz
# calculated 3 signatures for 105 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000614895.1_ASM61489v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000614895.1_ASM61489v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000626635.1_ASM62663v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000626635.1_ASM62663v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000626635.1_ASM62663v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000626635.1_ASM62663v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.fna.gz
# calculated 3 signatures for 298 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.fna.gz
# calculated 3 signatures for 179 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000785025.1_ASM78502v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000785025.1_ASM78502v1_genomic.fna.gz
# calculated 3 signatures for 77 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000785025.1_ASM78502v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000785025.1_ASM78502v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000814325.1_ASM81432v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000814325.1_ASM81432v1_genomic.fna.gz
# calculated 3 signatures for 55 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000814325.1_ASM81432v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000814325.1_ASM81432v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000821925.1_34AVR_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000821925.1_34AVR_genomic.fna.gz
# calculated 3 signatures for 68 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000821925.1_34AVR_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000821925.1_34AVR_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000938735.2_ASM93873v2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000938735.2_ASM93873v2_genomic.fna.gz
# calculated 3 signatures for 188 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000938735.2_ASM93873v2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000938735.2_ASM93873v2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000974365.1_ASM97436v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000974365.1_ASM97436v1_genomic.fna.gz
# calculated 3 signatures for 212 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000974365.1_ASM97436v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000974365.1_ASM97436v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001049535.1_3731_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001049535.1_3731_genomic.fna.gz
# calculated 3 signatures for 175 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001049535.1_3731_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001049535.1_3731_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001049555.1_7330_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001049555.1_7330_genomic.fna.gz
# calculated 3 signatures for 407 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001049555.1_7330_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001049555.1_7330_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001055755.1_ASM105575v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001055755.1_ASM105575v1_genomic.fna.gz
# calculated 3 signatures for 351 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001055755.1_ASM105575v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001055755.1_ASM105575v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001304045.1_ASM130404v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001304045.1_ASM130404v1_genomic.fna.gz
# calculated 3 signatures for 307 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001304045.1_ASM130404v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001304045.1_ASM130404v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001310955.1_ASM131095v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001310955.1_ASM131095v1_genomic.fna.gz
# calculated 3 signatures for 75 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001310955.1_ASM131095v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001310955.1_ASM131095v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001373135.1_2e6A_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001373135.1_2e6A_assembly_genomic.fna.gz
# calculated 3 signatures for 1730 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001373135.1_2e6A_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001373135.1_2e6A_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001398875.1_Mother10-2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001398875.1_Mother10-2_genomic.fna.gz
# calculated 3 signatures for 69 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001398875.1_Mother10-2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001398875.1_Mother10-2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001405895.1_14207_7_22_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001405895.1_14207_7_22_genomic.fna.gz
# calculated 3 signatures for 52 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001405895.1_14207_7_22_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001405895.1_14207_7_22_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001405935.1_13414_6_56_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001405935.1_13414_6_56_genomic.fna.gz
# calculated 3 signatures for 23 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001405935.1_13414_6_56_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001405935.1_13414_6_56_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001413955.1_ASM141395v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001413955.1_ASM141395v1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001413955.1_ASM141395v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001413955.1_ASM141395v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001443605.1_ASM144360v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001443605.1_ASM144360v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001443605.1_ASM144360v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001443605.1_ASM144360v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001548195.1_ASM154819v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001548195.1_ASM154819v1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001548195.1_ASM154819v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001548195.1_ASM154819v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001578565.1_ASM157856v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001578565.1_ASM157856v1_genomic.fna.gz
# calculated 3 signatures for 108 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001578565.1_ASM157856v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001578565.1_ASM157856v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001595155.1_CFSAN033860_01.0_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001595155.1_CFSAN033860_01.0_genomic.fna.gz
# calculated 3 signatures for 136 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001595155.1_CFSAN033860_01.0_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001595155.1_CFSAN033860_01.0_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001603535.1_ASM160353v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001603535.1_ASM160353v1_genomic.fna.gz
# calculated 3 signatures for 659 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001603535.1_ASM160353v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001603535.1_ASM160353v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001603695.1_ASM160369v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001603695.1_ASM160369v1_genomic.fna.gz
# calculated 3 signatures for 260 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001603695.1_ASM160369v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001603695.1_ASM160369v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001614375.1_ASM161437v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001614375.1_ASM161437v1_genomic.fna.gz
# calculated 3 signatures for 423 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001614375.1_ASM161437v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001614375.1_ASM161437v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001659685.2_ASM165968v2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001659685.2_ASM165968v2_genomic.fna.gz
# calculated 3 signatures for 81 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001659685.2_ASM165968v2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001659685.2_ASM165968v2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001693695.1_ASM169369v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001693695.1_ASM169369v1_genomic.fna.gz
# calculated 3 signatures for 14 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001693695.1_ASM169369v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001693695.1_ASM169369v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001761325.1_ASM176132v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001761325.1_ASM176132v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001761325.1_ASM176132v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001761325.1_ASM176132v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001816245.1_ASM181624v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001816245.1_ASM181624v1_genomic.fna.gz
# calculated 3 signatures for 102 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001816245.1_ASM181624v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001816245.1_ASM181624v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001915365.1_ASM191536v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001915365.1_ASM191536v1_genomic.fna.gz
# calculated 3 signatures for 580 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001915365.1_ASM191536v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001915365.1_ASM191536v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_002036985.1_ASM203698v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_002036985.1_ASM203698v1_genomic.fna.gz
# calculated 3 signatures for 84 sequences in 2018-test_datasets/bacteroides/genomic/GCA_002036985.1_ASM203698v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_002036985.1_ASM203698v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900032635.1_14555_6_27_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900032635.1_14555_6_27_genomic.fna.gz
# calculated 3 signatures for 78 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900032635.1_14555_6_27_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900032635.1_14555_6_27_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900104585.1_PRJEB16348_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900104585.1_PRJEB16348_genomic.fna.gz
# calculated 3 signatures for 6 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900104585.1_PRJEB16348_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900104585.1_PRJEB16348_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 76 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 38 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 74 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 89 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 58 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 37 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900128475.1_PRJEB18047_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900128475.1_PRJEB18047_genomic.fna.gz
# calculated 3 signatures for 25 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900128475.1_PRJEB18047_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900128475.1_PRJEB18047_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 13 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_genomic.fna.gz
# calculated 3 signatures for 11 sequences in 2018-test_datasets/bacteroides/genomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_genomic.fna.gz
# saved signature(s) to sigs/bacteroides/genomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_genomic.sig. Note: signature license is CC0.

# %%
##worker Bee

# !mkdir -p sigs/bacteroides/genomic2
# !for infile in 2018-test_datasets/bacteroides/genomic2/*fna.gz; \
do out_name=$(basename $infile .fna.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/bacteroides/genomic/${out_name}.sig ${infile}; done
# Out:
# mv: cannot stat 'sigs/bacteroides/genomic/*protein.sig': No such file or directory

# %%
# Using the code above, and the sourmash compute help message, calculate signatures for proteins
# !sourmash compute -h

# !mkdir -p sigs/bacteroides/proteomic
# !for infile in 2018-test_datasets/bacteroides/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/bacteroides/proteomic/${out_name}.sig ${infile}; done
# Out:
# usage: sourmash [--protein] [--no-protein] [--dayhoff] [--no-dayhoff] [--dna]
#                 [--no-dna] [-q] [--input-is-protein] [-k KSIZES]
#                 [-n NUM_HASHES] [--check-sequence] [-f] [-o OUTPUT]
#                 [--singleton] [--merge MERGED] [--name-from-first]
#                 [--input-is-10x] [--count-valid-reads COUNT_VALID_READS]
#                 [--write-barcode-meta-csv WRITE_BARCODE_META_CSV]
#                 [-p PROCESSES] [--save-fastas SAVE_FASTAS]
#                 [--line-count LINE_COUNT] [--track-abundance]
#                 [--scaled SCALED] [--seed SEED] [--randomize]
#                 [--license LICENSE]
#                 [--rename-10x-barcodes RENAME_10X_BARCODES]
#                 [--barcodes-file BARCODES_FILE]
#                 filenames [filenames ...]
# sourmash: error: unrecognized arguments: -h

# %%
# Now you can use sourmash compare to compare signatures that were calculated with the same k size, the same 
# molecule type, and the same encoding (e.g. dayoff or h-p).
# Take a look at the metapallette paper for some applications of k-sizes to detection of relatedness across
# evolutionary distances, or take our word that k = 21 ~ genus level similarlity, k = 31 ~ species level 
# similarity, and k = 51 ~ strain level similarity. https://msystems.asm.org/content/1/3/e00020-16
# !mkdir -p sourmash_compare
# !sourmash compare -k 31 -o sourmash_compare/bacteroides_k31_dna_comp sigs/bacteroides/genomic/*.sig
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.                                                    _assembly_genomic.sig
# downsampling to scaled value of 2000
#
# min similarity in matrix: 0.000
# saving labels to: sourmash_compare/bacteroides_k31_dna_comp.labels.txt
# saving distance matrix to: sourmash_compare/bacteroides_k31_dna_comp

# %%
# Sourmash has built-in plotting capabilities that you can use to visualize the comparison matrix
# You can open these pdf files from your computer, or go back to the jupyter dashboard an click 
# on them to open view them.
# !sourmash plot --labels --pdf sourmash_compare/bacteroides_k31_dna_comp
# %mv *.pdf /mnt/c/Users/user/Desktop/TESTcsv/

# %%
# Alternatively, you can output the sourmash compare matrix as a csv, and import it into R to visualize:
# !sourmash compare -k 31 --csv sourmash_compare/bacteroides_k31_dna_comp.csv sigs/bacteroides/genomic/*.sig
# see this link for generic R code to visualize the matrix:
# https://sourmash.readthedocs.io/en/latest/other-languages.html#r-code-for-working-with-compare-output

# %mv sourmash_compare/*.csv /mnt/c/Users/user/Desktop/TESTcsv/
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.                                                    _assembly_genomic.sig
# downsampling to scaled value of 2000
#
# min similarity in matrix: 0.000

# %% [markdown]
# ## Your next rotation task!
#
# Use this notebook and sourmash help messages to create the following signatures for all files in the bacteroides, denticola, and gingivalis folders:
# + DNA k = 21, 31, 51; scaled = 2000
# + RNA k = 21, 31, 51; scaled = 2000
# + protein k = 7, 11, 17; scaled = 2000; no encoding
# + protein k = 7, 11, 17; scaled = 2000; dayhoff encoding
# + protein k = 7, 11, 17; scaled = 2000; hp encoding
#
# Then, generate `sourmash compare` matrices for each set of signatures (i.e. one for denticola DNA k = 21, scaled = 2000). In total, this will be 45 sourmash compare matrices. Make sure you carefully select a consistent naming scheme so you will be able to tell the difference between each of these.
#
# Then, generate visualizations for these compare matrices. We want to know whether these accurately capture taxonomic relationships across evolutionary distances. Feel free to be creative with visualizations! You can use built-in sourmash plots, use the R code linked above, or even explore things like tanglegrams to compare a two trees.

# %% [markdown]
# *here I got really overwhelmed, so this is what I will want to be able to run in rstudio markdowns once i figure out how to install python and packages for it... >.< *

# %% [markdown]
# Note: where does 45 come from? well: #of k's to try (3) * versions (5) * #plots (3)

# %%
#!git clone https://github.com/bluegenes/2018-test_datasets.git
##Download files
#!python 2018-test_datasets/download_genbank_datasets.py --genbank --protein --rna --subfolder 2018-test_datasets/denticola.csv
#!python 2018-test_datasets/download_genbank_datasets.py --genbank --protein --rna --subfolder 2018-test_datasets/bacteroides.csv
#!python 2018-test_datasets/download_genbank_datasets.py --genbank --protein --rna --subfolder 2018-test_datasets/gingivalis.csv

#count up
# look and see how many genomes were downloaded for denticola
#!ls 2018-test_datasets/denticola/genomic/ | wc -l
#!ls 2018-test_datasets/denticola/genomic/



#make a dir for the signature for each genome in the dataset (6, 3orgs*2spaces)
# !mkdir -p sigs/bacteroides/genomic
# !mkdir -p sigs/bacteroides/proteomic

# !mkdir -p sigs/denticola/genomic
# !mkdir -p sigs/denticola/proteomic

# !mkdir -p sigs/gingivalis/genomic
# !mkdir -p sigs/gingivalis/proteomic

#unzip and compute signature
# !for infile in 2018-test_datasets/bacteroides/genomic/*fna.gz; do out_name=$(basename $infile .fna.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/bacteroides/genomic/${out_name}.sig ${infile}; done

# !for infile in 2018-test_datasets/bacteroides/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/bacteroides/proteomic/${out_name}.sig ${infile}; done


# compare matrix as a csv, and import it into R to visualize:
# !sourmash compare -k 31 --csv sourmash_compare/bacteroides_k31_dna_comp.csv sigs/bacteroides/genomic/*.sig
# see this link for generic R code to visualize the matrix:
# https://sourmash.readthedocs.io/en/latest/other-languages.html#r-code-for-working-with-compare-output

# %mv sourmash_compare/*.csv /mnt/c/Users/user/Desktop/TESTcsv/

# %%
#make a dir for the signature for each genome in the dataset (6, 3orgs*2spaces)
# !mkdir -p sigs/bacteroides/genomic
# !mkdir -p sigs/bacteroides/proteomic

# !mkdir -p sigs/denticola/genomic
# !mkdir -p sigs/denticola/proteomic

# !mkdir -p sigs/gingivalis/genomic
# !mkdir -p sigs/gingivalis/proteomic

# %%
#unzip and compute signature

# !for infile in 2018-test_datasets/bacteroides/genomic/*fna.gz; do out_name=$(basename $infile .fna.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/bacteroides/genomic/${out_name}.sig ${infile}; done
# !for infile in 2018-test_datasets/bacteroides/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/bacteroides/proteomic/${out_name}.sig ${infile}; done


# !for infile in 2018-test_datasets/denticola/genomic/*fna.gz; do out_name=$(basename $infile .fna.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/denticola/genomic/${out_name}.sig ${infile}; done
# !for infile in 2018-test_datasets/denticola/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/denticola/proteomic/${out_name}.sig ${infile}; done


# !for infile in 2018-test_datasets/gingivalis/genomic/*fna.gz; do out_name=$(basename $infile .fna.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/gingivalis/genomic/${out_name}.sig ${infile}; done
# !for infile in 2018-test_datasets/gingivalis/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 21,31,51 --scaled 2000 --track-abundance -o sigs/gingivalis/proteomic/${out_name}.sig ${infile}; done
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000011065.1_ASM1106v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000011065.1_ASM1106v1_genomic.fna.gz
# calculated 3 signatures for 2 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000011065.1_ASM1106v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000011065.1_ASM1106v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000157015.1_ASM15701v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000157015.1_ASM15701v1_genomic.fna.gz
# calculated 3 signatures for 33 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000157015.1_ASM15701v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000157015.1_ASM15701v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.fna.gz
# calculated 3 signatures for 5 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000159855.2_Bact_sp_3_2_5_V2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000163055.2_ASM16305v2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000163055.2_ASM16305v2_genomic.fna.gz
# calculated 3 signatures for 2 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000163055.2_ASM16305v2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000163055.2_ASM16305v2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.fna.gz
# calculated 3 signatures for 76 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000224595.1_Prevotella_sp_C561_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.fna.gz
# calculated 3 signatures for 19 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000373705.1_ASM37370v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000373705.1_ASM37370v1_genomic.fna.gz
# calculated 3 signatures for 50 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000373705.1_ASM37370v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000373705.1_ASM37370v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.fna.gz
# calculated 3 signatures for 6 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000431275.1_MGS755_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000431275.1_MGS755_genomic.fna.gz
# calculated 3 signatures for 114 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000431275.1_MGS755_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000431275.1_MGS755_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000432495.1_MGS558_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000432495.1_MGS558_genomic.fna.gz
# calculated 3 signatures for 175 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000432495.1_MGS558_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000432495.1_MGS558_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000466425.1_ASM46642v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000466425.1_ASM46642v1_genomic.fna.gz
# calculated 3 signatures for 103 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000466425.1_ASM46642v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000466425.1_ASM46642v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000495955.1_NUHP2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000495955.1_NUHP2_genomic.fna.gz
# calculated 3 signatures for 59 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000495955.1_NUHP2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000495955.1_NUHP2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000501415.1_BorBurgIPT48_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000501415.1_BorBurgIPT48_genomic.fna.gz
# calculated 3 signatures for 395 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000501415.1_BorBurgIPT48_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000501415.1_BorBurgIPT48_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.fna.gz
# calculated 3 signatures for 13 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.fna.gz
# calculated 3 signatures for 48 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000550025.1_Stap_aure_M1496_V1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000598325.1_ASM59832v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000598325.1_ASM59832v1_genomic.fna.gz
# calculated 3 signatures for 449 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000598325.1_ASM59832v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000598325.1_ASM59832v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000611675.1_ASM61167v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000611675.1_ASM61167v1_genomic.fna.gz
# calculated 3 signatures for 48 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000611675.1_ASM61167v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000611675.1_ASM61167v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000614865.1_ASM61486v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000614865.1_ASM61486v1_genomic.fna.gz
# calculated 3 signatures for 92 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000614865.1_ASM61486v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000614865.1_ASM61486v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000614895.1_ASM61489v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000614895.1_ASM61489v1_genomic.fna.gz
# calculated 3 signatures for 105 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000614895.1_ASM61489v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000614895.1_ASM61489v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000626635.1_ASM62663v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000626635.1_ASM62663v1_genomic.fna.gz
# calculated 3 signatures for 1 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000626635.1_ASM62663v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000626635.1_ASM62663v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.fna.gz
# calculated 3 signatures for 298 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000707425.1_CFSAN007430_01.0_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.fna.gz
# calculated 3 signatures for 179 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000759315.1_04_NF40_HMP9302v01_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000785025.1_ASM78502v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000785025.1_ASM78502v1_genomic.fna.gz
# calculated 3 signatures for 77 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000785025.1_ASM78502v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000785025.1_ASM78502v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000814325.1_ASM81432v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000814325.1_ASM81432v1_genomic.fna.gz
# calculated 3 signatures for 55 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000814325.1_ASM81432v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000814325.1_ASM81432v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000821925.1_34AVR_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000821925.1_34AVR_genomic.fna.gz
# calculated 3 signatures for 68 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000821925.1_34AVR_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000821925.1_34AVR_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000938735.2_ASM93873v2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000938735.2_ASM93873v2_genomic.fna.gz
# calculated 3 signatures for 188 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000938735.2_ASM93873v2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000938735.2_ASM93873v2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_000974365.1_ASM97436v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_000974365.1_ASM97436v1_genomic.fna.gz
# calculated 3 signatures for 212 sequences in 2018-test_datasets/bacteroides/genomic/GCA_000974365.1_ASM97436v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_000974365.1_ASM97436v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001049535.1_3731_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001049535.1_3731_genomic.fna.gz
# calculated 3 signatures for 175 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001049535.1_3731_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001049535.1_3731_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001049555.1_7330_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001049555.1_7330_genomic.fna.gz
# calculated 3 signatures for 407 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001049555.1_7330_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001049555.1_7330_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001055755.1_ASM105575v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001055755.1_ASM105575v1_genomic.fna.gz
# calculated 3 signatures for 351 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001055755.1_ASM105575v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001055755.1_ASM105575v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001304045.1_ASM130404v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001304045.1_ASM130404v1_genomic.fna.gz
# calculated 3 signatures for 307 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001304045.1_ASM130404v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001304045.1_ASM130404v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001310955.1_ASM131095v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001310955.1_ASM131095v1_genomic.fna.gz
# calculated 3 signatures for 75 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001310955.1_ASM131095v1_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001310955.1_ASM131095v1_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001373135.1_2e6A_assembly_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001373135.1_2e6A_assembly_genomic.fna.gz
# calculated 3 signatures for 1730 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001373135.1_2e6A_assembly_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001373135.1_2e6A_assembly_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001398875.1_Mother10-2_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001398875.1_Mother10-2_genomic.fna.gz
# calculated 3 signatures for 69 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001398875.1_Mother10-2_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001398875.1_Mother10-2_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001405895.1_14207_7_22_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001405895.1_14207_7_22_genomic.fna.gz
# calculated 3 signatures for 52 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001405895.1_14207_7_22_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001405895.1_14207_7_22_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001405935.1_13414_6_56_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_001405935.1_13414_6_56_genomic.fna.gz
# calculated 3 signatures for 23 sequences in 2018-test_datasets/bacteroides/genomic/GCA_001405935.1_13414_6_56_genomic.fna.gz
# == This is sourmash version 2.2.0. ==s/genomic/GCA_001405935.1_13414_6_56_genomic.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/bacteroides/genomic/GCA_001413955.1_ASM141395v1_genomic.fna.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/genomic/GCA_
1_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_001897595.1_ASM189759v1_protein.faa.gz
# calculated 3 signatures for 4208 sequences in 2018-test_datasets/gingivalis/protein/GCA_001897595.1_ASM189759v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_001897595.1_ASM189759v1_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_001898165.1_ASM189816v1_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_001898165.1_ASM189816v1_protein.faa.gz
# calculated 3 signatures for 2942 sequences in 2018-test_datasets/gingivalis/protein/GCA_001898165.1_ASM189816v1_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_001898165.1_ASM189816v1_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900085525.1_12045_7_37_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900085525.1_12045_7_37_protein.faa.gz
# calculated 3 signatures for 4961 sequences in 2018-test_datasets/gingivalis/protein/GCA_900085525.1_12045_7_37_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900085525.1_12045_7_37_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900089535.1_A04_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900089535.1_A04_protein.faa.gz
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/command_compute.py", line 567, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for '2018-test_datasets/gingivalis/protein/GCA_900089535.1_A04_protein.faa.gz'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900107785.1_IMG-taxon_2654588140_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900107785.1_IMG-taxon_2654588140_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 3334 sequences in 2018-test_datasets/gingivalis/protein/GCA_900107785.1_IMG-taxon_2654588140_annotated_assembly_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900107785.1_IMG-taxon_2654588140_annotated_assembly_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900112105.1_IMG-taxon_2622736505_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900112105.1_IMG-taxon_2622736505_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 3560 sequences in 2018-test_datasets/gingivalis/protein/GCA_900112105.1_IMG-taxon_2622736505_annotated_assembly_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900112105.1_IMG-taxon_2622736505_annotated_assembly_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900112395.1_IMG-taxon_2634166310_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900112395.1_IMG-taxon_2634166310_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 3925 sequences in 2018-test_datasets/gingivalis/protein/GCA_900112395.1_IMG-taxon_2634166310_annotated_assembly_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900112395.1_IMG-taxon_2634166310_annotated_assembly_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900114365.1_IMG-taxon_2651870357_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900114365.1_IMG-taxon_2651870357_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 4005 sequences in 2018-test_datasets/gingivalis/protein/GCA_900114365.1_IMG-taxon_2651870357_annotated_assembly_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900114365.1_IMG-taxon_2651870357_annotated_assembly_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900128985.1_IMG-taxon_2695420931_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900128985.1_IMG-taxon_2695420931_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 4015 sequences in 2018-test_datasets/gingivalis/protein/GCA_900128985.1_IMG-taxon_2695420931_annotated_assembly_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900128985.1_IMG-taxon_2695420931_annotated_assembly_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900141875.1_IMG-taxon_2700988694_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900141875.1_IMG-taxon_2700988694_annotated_assembly_protein.faa.gz
# calculated 3 signatures for 4109 sequences in 2018-test_datasets/gingivalis/protein/GCA_900141875.1_IMG-taxon_2700988694_annotated_assembly_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900141875.1_IMG-taxon_2700988694_annotated_assembly_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900157215.1_Strain_3-3_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900157215.1_Strain_3-3_protein.faa.gz
# calculated 3 signatures for 1779 sequences in 2018-test_datasets/gingivalis/protein/GCA_900157215.1_Strain_3-3_protein.faa.gz
# == This is sourmash version 2.2.0. ==/proteomic/GCA_900157215.1_Strain_3-3_protein.sig. Note: signature license is CC0.
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# setting num_hashes to 0 because --scaled is set
# computing signatures for files: 2018-test_datasets/gingivalis/protein/GCA_900157325.1_3A1_protein.faa.gz
# Computing signature for ksizes: [21, 31, 51]
# Computing only nucleotide (and not protein) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/gingivalis/protein/GCA_900157325.1_3A1_protein.faa.gz
# calculated 3 signatures for 1846 sequences in 2018-test_datasets/gingivalis/protein/GCA_900157325.1_3A1_protein.faa.gz
# saved signature(s) to sigs/gingivalis/proteomic/GCA_900157325.1_3A1_protein.sig. Note: signature license is CC0.

# %%
#%pwd
#!mkdir -p sourmash_compare/compare_CSVs

# 31-mer
##Bacteroides, genomic
#!sourmash compare -k 31 -o sourmash_compare/bacteroides_k31_genomic_comp sigs/bacteroides/genomic/*.sig
#!sourmash plot --labels --pdf sourmash_compare/bacteroides_k31_genomic_comp
#%mv *.pdf /mnt/c/Users/user/Desktop/CheckPlotPDFs/
#!sourmash compare -k 31 --csv sourmash_compare/compare_CSVs/bacteroides_k31_genomic_comp.csv sigs/bacteroides/genomic/*.sig
#%mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/

##Bacteroides, proteomic
#!sourmash compare -k 31 -o sourmash_compare/bacteroides_k31_proteomic_comp sigs/bacteroides/proteomic/*.sig
#!sourmash plot --labels --pdf sourmash_compare/bacteroides_k31_proteomic_comp
#%mv *.pdf /mnt/c/Users/user/Desktop/CheckPlotPDFs/
##This doesnt appear useful (looks like only one seq is present)
#!sourmash compare -k 31 --csv sourmash_compare/compare_CSVs/bacteroides_k31_proteomic_comp.csv sigs/bacteroides/proteomic/*.sig
#%mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loaded 40 signatures total.
# downsampling to scaled value of 2000
#
# min similarity in matrix: 0.000

# %% [markdown]
# we gon make a turduckin style for loop:
#
# for space= genomic, proteomic
# for organism= bacteroides, gingivalis, denticola
# for k=31, 21, 51

# %%
# %%bash
#
#
# #unzip and compute signature
# #seqSpace = {"genomic", "proteomic"}
# #organism = {"bacteroides", "gingivalis", "denticola"}
# #kMer = {31, 21, 51}
#
# #for z in seqSpace:
# #    for y in organism:
# #        for x in kMer
#  #       do
#   #          sourmash compare -k (x) -o sourmash_compare/bacteroides_k31_genomic_comp sigs/bacteroides/genomic/*.sig
#    #     done
# #!sourmash plot --labels --pdf sourmash_compare/bacteroides_k31_genomic_comp
# #%mv *.pdf /mnt/c/Users/user/Desktop/CheckPlotPDFs/
# #!sourmash compare -k 31 --csv sourmash_compare/compare_CSVs/bacteroides_k31_genomic_comp.csv sigs/bacteroides/genomic/*.sig
# #%mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/
#
# #!sourmash compare -k 31 -o sourmash_compare/bacteroides_k31_genomic_comp sigs/bacteroides/genomic/*.sig
# #!sourmash plot --labels --pdf sourmash_compare/bacteroides_k31_genomic_comp
# #%mv *.pdf /mnt/c/Users/user/Desktop/CheckPlotPDFs/
# #!sourmash compare -k 31 --csv sourmash_compare/compare_CSVs/bacteroides_k31_genomic_comp.csv sigs/bacteroides/genomic/*.sig
# #%mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/
#
#
# echo hello
# Out:
# hello

# %%
# %%bash
# for k in 21 31 51
#     do
#    for org in bacteroides gingivalis denticola
#        do
#         for mol in genomic
#             do
# sourmash compare -k ${k} -o sourmash_compare/${org}_k${k}_${mol}_comp sigs/${org}/${mol}/*.sig
# sourmash plot --labels --pdf sourmash_compare/${org}_k${k}_${mol}_comp
# sourmash compare -k ${k} --csv sourmash_compare/compare_CSVs/${org}_k${k}_${mol}_comp.csv sigs/${org}/${mol}/*.sig
# done
# done
# done
#
# for k in 7 9 12 21
#     do
#    for org in bacteroides gingivalis denticola
#        do
#         for mol in proteomic
#             do
# sourmash compare -k ${k} -o sourmash_compare/${org}_k${k}_${mol}_comp sigs/${org}/${mol}/*.sig
# sourmash plot --labels --pdf sourmash_compare/${org}_k${k}_${mol}_comp
# sourmash compare -k ${k} --csv sourmash_compare/compare_CSVs/${org}_k${k}_${mol}_comp.csv sigs/${org}/${mol}/*.sig
# done
# done
# done
#
# mv *.pdf /mnt/c/Users/user/Desktop/CheckPlotPDFs/
# mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/
# Out:
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# min similarity in matrix: 0.000
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/bacteroides_k21_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/bacteroides_k21_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/bacteroides_k21_genomic_comp...
# ...got 61 x 61 matrix.
# loading labels from sourmash_compare/bacteroides_k21_genomic_comp.labels.txt
# saving histogram of matrix values => bacteroides_k21_genomic_comp.hist.pdf
# wrote dendrogram to: bacteroides_k21_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: bacteroides_k21_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/gingivalis_k21_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/gingivalis_k21_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/gingivalis_k21_genomic_comp...
# ...got 69 x 69 matrix.
# loading labels from sourmash_compare/gingivalis_k21_genomic_comp.labels.txt
# saving histogram of matrix values => gingivalis_k21_genomic_comp.hist.pdf
# wrote dendrogram to: gingivalis_k21_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: gingivalis_k21_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/denticola_k21_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/denticola_k21_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/denticola_k21_genomic_comp...
# ...got 69 x 69 matrix.
# loading labels from sourmash_compare/denticola_k21_genomic_comp.labels.txt
# saving histogram of matrix values => denticola_k21_genomic_comp.hist.pdf
# wrote dendrogram to: denticola_k21_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: denticola_k21_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/bacteroides_k31_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/bacteroides_k31_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/bacteroides_k31_genomic_comp...
# ...got 61 x 61 matrix.
# loading labels from sourmash_compare/bacteroides_k31_genomic_comp.labels.txt
# saving histogram of matrix values => bacteroides_k31_genomic_comp.hist.pdf
# wrote dendrogram to: bacteroides_k31_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: bacteroides_k31_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/gingivalis_k31_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/gingivalis_k31_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/gingivalis_k31_genomic_comp...
# ...got 69 x 69 matrix.
# loading labels from sourmash_compare/gingivalis_k31_genomic_comp.labels.txt
# saving histogram of matrix values => gingivalis_k31_genomic_comp.hist.pdf
# wrote dendrogram to: gingivalis_k31_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: gingivalis_k31_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/denticola_k31_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/denticola_k31_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/denticola_k31_genomic_comp...
# ...got 69 x 69 matrix.
# loading labels from sourmash_compare/denticola_k31_genomic_comp.labels.txt
# saving histogram of matrix values => denticola_k31_genomic_comp.hist.pdf
# wrote dendrogram to: denticola_k31_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: denticola_k31_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/bacteroides_k51_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/bacteroides_k51_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/bacteroides_k51_genomic_comp...
# ...got 61 x 61 matrix.
# loading labels from sourmash_compare/bacteroides_k51_genomic_comp.labels.txt
# saving histogram of matrix values => bacteroides_k51_genomic_comp.hist.pdf
# wrote dendrogram to: bacteroides_k51_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: bacteroides_k51_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 61 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/gingivalis_k51_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/gingivalis_k51_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/gingivalis_k51_genomic_comp...
# ...got 69 x 69 matrix.
# loading labels from sourmash_compare/gingivalis_k51_genomic_comp.labels.txt
# saving histogram of matrix values => gingivalis_k51_genomic_comp.hist.pdf
# wrote dendrogram to: gingivalis_k51_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: gingivalis_k51_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# saving labels to: sourmash_compare/denticola_k51_genomic_comp.labels.txt
# saving distance matrix to: sourmash_compare/denticola_k51_genomic_comp
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/denticola_k51_genomic_comp...
# ...got 69 x 69 matrix.
# loading labels from sourmash_compare/denticola_k51_genomic_comp.labels.txt
# saving histogram of matrix values => denticola_k51_genomic_comp.hist.pdf
# wrote dendrogram to: denticola_k51_genomic_comp.dendro.pdf
# wrote numpy distance matrix to: denticola_k51_genomic_comp.matrix.pdf
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loaded 69 signatures total.
# downsampling to scaled value of 2000
#
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/bacteroides_k7_proteomic_comp...
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/commands.py", line 218, in plot
#     D = numpy.load(open(D_filename, 'rb'))
# FileNotFoundError: [Errno 2] No such file or directory: 'sourmash_compare/bacteroides_k7_proteomic_comp'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/gingivalis/proteomic/GCA_000007585.1_ASM758v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/gingivalis/proteomic/GCA_000007585.1_ASM758v1_protein.sig
# loading sigs/gingivalis/proteomic/GCA_000010505.1_ASM1050v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/gingivalis/proteomic/GCA_000010505.1_ASM1050v1_protein.sig
# loading sigs/gingivalis/proteomic/GCA_000064305.2_ASM6430v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/gingivalis/proteomic/GCA_000064305.2_ASM6430v2_protein.sig
# loading sigs/gingivalis/proteomic/GCA_000158515.2_Bacteroides_sp_4_3_47FAA_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/gingivalis/proteomic/GCA_000158515.2_Bacteroides_sp_4_3_47FAA_V2_protein.sig
# loading sigs/gingivalis/proteomic/GCA_000162415.1_ASM16241v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/gingivalis/proteomic/GCA_000162415.1_ASM16241v1_protein.sig
# loading sigs/gingivalis/proteomic/GCA_
protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_000501555.1_BorAfzIPT109_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_000502195.1_BorAfzIPT138_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_000818865.1_ASM81886v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_001567655.1_ASM156765v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_001604335.1_ASM160433v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_001896735.1_ASM189673v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_001940825.1_ASM194082v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_002009835.1_ASM200983v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/denticola/proteomic/GCA_900147745.1_138_1_protein.sig
# loaded 49 signatures total.
# downsampling to scaled value of 2000

# %%
# %%bash
# for k in 7
# #9 12
#     do
#    for org in bacteroides
# #gingivalis denticola
#        do
#         for mol in proteomic
#             do
# sourmash compare -k ${k} -o sourmash_compare/${org}_k${k}_${mol}_comp sigs/${org}/${mol}/*.sig
# sourmash plot --labels --pdf sourmash_compare/bacteroides_k${k}_genomic_comp
# sourmash compare -k ${k} --csv sourmash_compare/compare_CSVs/${org}_k${k}_${mol}_comp.csv sigs/${org}/${mol}/*.sig
# done
# done
# done
# mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/Test
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/bacteroides_k7_genomic_comp...
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/commands.py", line 218, in plot
#     D = numpy.load(open(D_filename, 'rb'))
# FileNotFoundError: [Errno 2] No such file or directory: 'sourmash_compare/bacteroides_k7_genomic_comp'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/bacteroides_k9_genomic_comp...
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/commands.py", line 218, in plot
#     D = numpy.load(open(D_filename, 'rb'))
# FileNotFoundError: [Errno 2] No such file or directory: 'sourmash_compare/bacteroides_k9_genomic_comp'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# ...
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading comparison matrix from sourmash_compare/bacteroides_k12_genomic_comp...
# Traceback (most recent call last):
#   File "/home/hehouts/miniconda3/envs/rotation/bin/sourmash", line 11, in <module>
#     sys.exit(main())
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/home/hehouts/miniconda3/envs/rotation/lib/python3.7/site-packages/sourmash/commands.py", line 218, in plot
#     D = numpy.load(open(D_filename, 'rb'))
# FileNotFoundError: [Errno 2] No such file or directory: 'sourmash_compare/bacteroides_k12_genomic_comp'
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures

# %%
# %%bash
# for k in 7 9 12
#     do
#    for org in bacteroides gingivalis denticola
#        do
#         for mol in proteomic
#             do
# sourmash plot --labels --pdf sourmash_compare/bacteroides_k${k}_genomic_comp
# done
# done
# done
# mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/
#
# #%mv *.pdf /mnt/c/Users/user/Desktop/CheckPlotPDFs/
# #%mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/
# Out:
# mv: cannot stat '*.pdf': No such file or directory

# %%
# 7-mer
#Bacteroides, proteomic
# !sourmash compare -k 7 -o sourmash_compare/bacteroides_k7_proteomic_comp sigs/bacteroides/proteomic/*.sig
#!sourmash plot --labels --pdf sourmash_compare/bacteroides_k7_proteomic_comp
#%mv *.pdf /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/Test

#!sourmash compare -k 7 --csv sourmash_compare/compare_CSVs/bacteroides_k7_proteomic_comp.csv sigs/bacteroides/proteomic/*.sig
#%mv sourmash_compare/compare_CSVs/*.csv /mnt/c/Users/user/Desktop/ROTATIONS/DIBlabRotationProject/CompCSVs/Test
# Out:
# == This is sourmash version 2.2.0. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# loading sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000011065.1_ASM1106v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000157015.1_ASM15701v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000159855.2_Bact_sp_3_2_5_V2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000163055.2_ASM16305v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000224595.1_Prevotella_sp_C561_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000273215.1_Bact_ovat_CL03T12C18_V1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000373705.1_ASM37370v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000403155.2_Bact_thet_dnLKV9_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000431275.1_MGS755_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000432495.1_MGS558_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000466425.1_ASM46642v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000495955.1_NUHP2_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000501415.1_BorBurgIPT48_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000542015.1_Stap_aure_FVRH6074_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000550025.1_Stap_aure_M1496_V1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000598325.1_ASM59832v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000611675.1_ASM61167v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614865.1_ASM61486v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000614895.1_ASM61489v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000626635.1_ASM62663v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000707425.1_CFSAN007430_01.0_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000759315.1_04_NF40_HMP9302v01_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000785025.1_ASM78502v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000814325.1_ASM81432v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000821925.1_34AVR_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000938735.2_ASM93873v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_000974365.1_ASM97436v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049535.1_3731_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001049555.1_7330_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001055755.1_ASM105575v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001304045.1_ASM130404v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001310955.1_ASM131095v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001373135.1_2e6A_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001398875.1_Mother10-2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405895.1_14207_7_22_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001405935.1_13414_6_56_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001413955.1_ASM141395v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001443605.1_ASM144360v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001548195.1_ASM154819v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001578565.1_ASM157856v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001595155.1_CFSAN033860_01.0_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603535.1_ASM160353v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001603695.1_ASM160369v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001614375.1_ASM161437v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001659685.2_ASM165968v2_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001693695.1_ASM169369v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001761325.1_ASM176132v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001816245.1_ASM181624v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_001915365.1_ASM191536v1_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_002036985.1_ASM203698v1_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900032635.1_14555_6_27_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900104585.1_PRJEB16348_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig
# Error in parsing signature; quitting.
# Exception: parse error: premature EOF
#
#                      (right here) ------^
#
#
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900128475.1_PRJEB18047_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig
# loading sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# warning: no signatures loaded at given ksize/molecule type from sigs/bacteroides/proteomic/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig
# loaded 0 signatures total.
# cannot mix scaled signatures with bounded signatures

# %%
# %ls sourmash_compare/bac
# Out:
# bacteroides_k21_genomic_comp
# bacteroides_k21_genomic_comp.labels.txt
# bacteroides_k21_proteomic_comp
# bacteroides_k21_proteomic_comp.labels.txt
# bacteroides_k31_genomic_comp
# bacteroides_k31_genomic_comp.csv
# bacteroides_k31_genomic_comp.labels.txt
# bacteroides_k31_proteomic_comp
# bacteroides_k31_proteomic_comp.labels.txt
# bacteroides_k51_genomic_comp
# bacteroides_k51_genomic_comp.labels.txt
# bacteroides_k51_proteomic_comp
# bacteroides_k51_proteomic_comp.labels.txt
# compare_CSVs/
# denticola_k21_genomic_comp
# denticola_k21_genomic_comp.labels.txt
# denticola_k21_proteomic_comp
# denticola_k21_proteomic_comp.labels.txt
# denticola_k31_genomic_comp
# denticola_k31_genomic_comp.labels.txt
# denticola_k31_proteomic_comp
# denticola_k31_proteomic_comp.labels.txt
# denticola_k51_genomic_comp
# denticola_k51_genomic_comp.labels.txt
# denticola_k51_proteomic_comp
# denticola_k51_proteomic_comp.labels.txt
# gingivalis_k21_genomic_comp
# gingivalis_k21_genomic_comp.labels.txt
# gingivalis_k21_proteomic_comp
# gingivalis_k21_proteomic_comp.labels.txt
# gingivalis_k31_genomic_comp
# gingivalis_k31_genomic_comp.labels.txt
# gingivalis_k31_proteomic_comp
# gingivalis_k31_proteomic_comp.labels.txt
# gingivalis_k51_genomic_comp
# gingivalis_k51_genomic_comp.labels.txt
# gingivalis_k51_proteomic_comp
# gingivalis_k51_proteomic_comp.labels.txt
